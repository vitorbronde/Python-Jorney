# %% [markdown]
# # Agenda

# %% [markdown]
# > Data: 23/09/2020<br>
# > Aula: 05 <br>
# > Módulo: 00 <br>
# > Instrutores: Bruno Vieira e Maurício Nascimento<br>
# > Turma: DSTN07

# %% [markdown]
# O objetivo dessa aula é explorar métodos de agrupamento a dataframes, aplicações de funções em colunas e linhas e também demonstrar a utilização de algumas funções específicas.

# %% [markdown]
# **Tópicos**:
#  - Funções Úteis
#  - Agregação de DataFrames (groupby e agg)
#  - Apply, Applymap, map
#  - Exercícios

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df_pokemons = pd.read_csv(r'C:\Users\vitor.silva\Desktop\Estudo Python\Python  - Digital\pokemon_data.csv')

# %% [markdown]
# # Pandas (Parte III)

# %% [markdown]
# ## Funções Úteis

# %% [markdown]
# Campos vazios podem surgir em nossos dados corriqueiramente. Eles têm diversas origens e, dependendo dessa origem, receberão diferentes tratamentos. De início vamos aprender a observar essas ocorrências e o tratamento mais simples para eles: Exclusão (nem sempre a mais indicada).

# %%
#Contagem NULL
df_pokemons.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
# dropar NAN
df_pokemons_sem_na =  df_pokemons.dropna()

# %% [markdown]
# <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html">Clique Aqui</a> para saber mais sobre o dropna()

# %%
# checar se há duplicados
df_pokemons.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Length: 800, dtype: bool

# %%
# dropa duplicados mantendo o primeiro que apareceu
df_pokemons.drop_duplicates(keep = 'first')
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]

# %%
# checar os elementos únicos de uma coluna (funciona melho com coluna qualitativa - categórica)
df_pokemons['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
# Replace
df_pokemons.replace({True : 'verdadeiro' , False : 'falso'})
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation   Legendary
# 0         65       65     45           1       falso
# 1         80       80     60           1       falso
# 2        100      100     80           1       falso
# 3        122      120     80           1       falso
# 4         60       50     65           1       falso
# ..       ...      ...    ...         ...         ...
# 795      100      150     50           6  verdadeiro
# 796      160      110    110           6  verdadeiro
# 797      150      130     70           6  verdadeiro
# 798      170      130     80           6  verdadeiro
# 799      130       90     70           6  verdadeiro
#
# [800 rows x 12 columns]

# %% [markdown]
# ##  Agregação (Group By & Aggregate)

# %% [markdown]
# A agregação é simplesmente a ação de olhar as estatísticas sob a perspectiva de grupos.

# %% [markdown]
# <img src="https://jakevdp.github.io/PythonDataScienceHandbook/figures/03.08-split-apply-combine.png" height=600 width=600>

# %% [markdown]
# Basicamente, os dados vão ser separados de acordo com um ou mais grups em comum ```(etapa de split)```. Então, a partir da separação desses grupos uma função vai ser aplicada ```(apply (sum))``` em cada subconjunto. No nosso exemplo essa função de soma. No final, ele combina o resultado agrupad ```(combine)```.

# %% [markdown]
# <img src="https://www.softwaretestingclass.com/wp-content/uploads/2013/06/sql_group_by_with_aggregate_function.gif" height=450 width=450>

# %% [markdown]
# Aqui vemos os grupos de departamento e extraímos a soma do salário por departamento.

# %%
# Soma de HP agrupada por Type 1
df_pokemons.groupby('Type 1').sum()
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1
# Bug       23080  3925    4897     4880     3717     4471   4256         222
# Dark      14302  2071    2740     2177     2314     2155   2361         125
# Dragon    15180  2666    3588     2764     3099     2843   2657         124
# Electric  15994  2631    3040     2917     3961     3243   3718         144
# Fairy      7642  1260    1046     1117     1335     1440    826          70
# Fighting   9824  1886    2613     1780     1434     1747   1784          91
# Fire      17025  3635    4408     3524     4627     3755   3871         167
# Flying     2711   283     315      265      377      290    410          22
# Ghost     15568  2062    2361     2598     2539     2447   2059         134
# Grass     24141  4709    5125     4956     5425     4930   4335         235
# Ground    11401  2361    3064     2715     1807     2008   2045         101
# Ice       10165  1728    1746     1714     1861     1831   1523          85
# Normal    31279  7573    7200     5865     5470     6245   7012         299
# Poison     7050  1883    2091     1927     1692     1803   1780          71
# Psychic   21706  4026    4073     3858     5609     4918   4645         193
# Rock      17280  2876    4086     4435     2787     3321   2460         152
# Steel     11957  1761    2503     3412     1823     2177   1492         104
# Water     33946  8071    8305     8170     8379     7898   7388         320
#
#           Legendary
# Type 1
# Bug               0
# Dark              2
# Dragon           12
# Electric          4
# Fairy             1
# Fighting          0
# Fire              5
# Flying            2
# Ghost             2
# Grass             3
# Ground            4
# Ice               2
# Normal            2
# Poison            0
# Psychic          14
# Rock              4
# Steel             4
# Water             4

# %%
#agrupar por mais de um grupo
df_pokemons.groupby(['Type 1' , 
                     'Legendary']).mean()
# Out:
#                              #          HP      Attack     Defense  \
# Type 1   Legendary
# Bug      False      334.492754   56.884058   70.971014   70.724638
# Dark     False      451.517241   64.655172   86.862069   68.689655
#          True       604.000000   98.000000  110.500000   92.500000
# Dragon   False      447.350000   72.650000  103.400000   78.150000
#          True       519.416667  101.083333  126.666667  100.083333
# Electric False      358.050000   57.325000   66.125000   65.425000
#          True       418.000000   84.500000   98.750000   75.000000
# Fairy    False      432.875000   70.875000   57.187500   63.875000
#          True       716.000000  126.000000  131.000000   95.000000
# Fighting False      363.851852   69.851852   96.777778   65.925926
# Fire     False      322.957447   67.085106   82.191489   64.531915
#          True       369.200000   96.400000  109.000000   98.200000
# Flying   False      714.500000   62.500000   50.000000   57.500000
#          True       641.000000   79.000000  107.500000   75.000000
# Ghost    False      486.466667   58.733333   71.366667   79.266667
#          True       487.000000  150.000000  110.000000  110.000000
# Grass    False      336.074627   65.940299   72.119403   70.283582
#          True       541.333333   97.000000   97.666667   82.333333
# Ground   False      333.750000   70.821429   88.000000   79.821429
#          True       514.000000   94.500000  150.000000  120.000000
# Ice      False      438.318182   70.818182   73.227273   68.818182
#          True       261.000000   85.000000   67.500000  100.000000
# Normal   False      315.625000   76.489583   72.083333   58.697917
#          True       489.500000  115.000000  140.000000  115.000000
# Poison   False      251.785714   67.250000   74.678571   68.821429
# Psychic  False      374.093023   67.720930   54.953488   61.000000
#          True       401.428571   79.571429  122.142857   88.214286
# Rock     False      370.650000   65.125000   89.925000   97.125000
#          True       613.500000   67.750000  122.250000  137.500000
# Steel    False      437.913043   60.434783   92.086957  126.652174
#          True       471.250000   92.750000   96.250000  124.750000
# Water    False      300.490741   71.120370   72.777778   71.990741
#          True       373.250000   97.500000  111.250000   98.750000
#
#                        Sp. Atk     Sp. Def       Speed  Generation
# Type 1   Legendary
# Bug      False       53.869565   64.797101   61.681159    3.217391
# Dark     False       70.620690   67.827586   73.689655    3.965517
#          True       133.000000   94.000000  112.000000    5.000000
# Dragon   False       72.900000   77.400000   72.350000    3.750000
#          True       136.750000  107.916667  100.833333    4.083333
# Electric False       86.275000   72.325000   82.275000    3.275000
#          True       127.500000   87.500000  106.750000    3.250000
# Fairy    False       75.250000   83.875000   45.437500    4.000000
#          True       131.000000   98.000000   99.000000    6.000000
# Fighting False       53.111111   64.703704   66.074074    3.370370
# Fire     False       86.000000   69.042553   73.276596    3.234043
#          True       117.000000  102.000000   85.400000    3.000000
# Flying   False       71.000000   60.000000   89.000000    6.000000
#          True       117.500000   85.000000  116.000000    5.000000
# Ghost    False       77.300000   74.233333   62.633333    4.200000
#          True       110.000000  110.000000   90.000000    4.000000
# Grass    False       76.343284   69.044776   59.701493    3.313433
#          True       103.333333  101.333333  111.666667    4.333333
# Ground   False       47.750000   59.571429   59.750000    3.035714
#          True       117.500000   85.000000   93.000000    4.000000
# Ice      False       75.727273   68.454545   63.090909    3.681818
#          True        97.500000  162.500000   67.500000    2.000000
# Normal   False       54.895833   62.656250   70.750000    3.031250
#          True       100.000000  115.000000  110.000000    4.000000
# Poison   False       60.428571   64.392857   63.571429    2.535714
# Psychic  False       88.302326   80.674419   70.348837    3.418605
#          True       129.428571  103.500000  115.714286    3.285714
# Rock     False       60.125000   71.775000   53.550000    3.300000
#          True        95.500000  112.500000   79.500000    5.000000
# Steel    False       61.217391   76.304348   49.739130    3.869565
#          True       103.750000  105.500000   87.000000    3.750000
# Water    False       72.305556   68.175926   65.027778    2.851852
#          True       142.500000  133.750000   91.250000    3.000000

# %%
# irá agregar o dataframe de acordo com as funções aplicadas dentro da lista
df_pokemons.groupby('Type 1').agg(['min', np.median, 'max'])
# Out:
#             #              HP             Attack             Defense         \
#           min median  max min median  max    min median  max     min median
# Type 1
# Bug        10  291.0  666   1   60.0   86     10   65.0  185      30   60.0
# Dark      197  509.0  717  35   65.0  126     50   88.0  150      30   70.0
# Dragon    147  443.5  718  41   80.0  125     50  113.5  180      35   90.0
# Electric   25  403.5  702  20   60.0   90     30   65.0  123      15   65.0
# Fairy      35  669.0  716  35   78.0  126     20   52.0  131      28   66.0
# Fighting   56  308.0  701  30   70.0  144     35  100.0  145      30   70.0
# Fire        4  289.5  721  38   70.0  115     30   84.5  160      37   64.0
# Flying    641  677.5  715  40   79.0   85     30   85.0  115      35   75.0
# Ghost      92  487.0  711  20   59.5  150     30   66.0  165      30   72.5
# Grass       1  372.0  673  30   65.5  123     27   70.0  132      30   66.0
# Ground     27  363.5  645  10   75.0  115     40   85.0  180      25   84.5
# Ice       124  371.5  713  36   70.0  110     30   67.0  130      15   75.0
# Normal     16  296.5  676  30   70.0  255      5   70.5  160       5   60.0
# Poison     23  139.5  691  35   67.5  105     43   74.0  106      35   67.0
# Psychic    63  386.0  720  20   68.0  190     20   57.0  190      15   65.0
# Rock       74  362.5  719  30   68.5  123     40   95.0  165      40  100.0
# Steel     208  379.0  707  40   60.0  100     24   89.0  150      50  120.0
# Water       7  275.0  693  20   70.0  170     10   72.0  155      20   70.0
#
#               Sp. Atk             Sp. Def             Speed              \
#           max     min median  max     min median  max   min median  max
# Type 1
# Bug       230      10   50.0  135      20   60.0  230     5   60.0  160
# Dark      125      30   65.0  140      30   65.0  130    20   70.0  125
# Dragon    130      30  105.0  180      30   90.0  150    40   90.0  120
# Electric  115      35   95.0  165      32   79.5  110    35   88.0  140
# Fairy      95      40   75.0  131      40   79.0  154    15   45.0   99
# Fighting   95      20   40.0  140      30   63.0  110    25   60.0  118
# Fire      140      15   85.0  159      40   67.5  154    20   78.5  126
# Flying     80      45  103.5  125      40   80.0   90    55  116.0  123
# Ghost     145      30   65.0  170      33   75.0  135    20   60.5  130
# Grass     131      24   75.0  145      30   66.0  129    10   58.5  145
# Ground    160      20   47.5  150      30   62.5  120    10   65.0  120
# Ice       184      30   77.5  130      30   70.0  200    25   62.0  110
# Normal    126      15   50.0  135      20   60.5  135     5   71.0  135
# Poison    120      30   60.0  100      40   60.5  123    25   62.5  130
# Psychic   160      23   95.0  194      20   90.0  160    20   80.0  180
# Rock      200      10   60.0  160      25   70.0  150    10   50.0  150
# Steel     230      24   55.0  150      37   80.0  150    23   50.0  110
# Water     180      10   70.0  180      20   65.0  160    15   65.0  122
#
#          Generation            Legendary
#                 min median max       min median    max
# Type 1
# Bug               1    3.0   6     False    0.0  False
# Dark              2    5.0   6     False    0.0   True
# Dragon            1    4.0   6     False    0.0   True
# Electric          1    4.0   6     False    0.0   True
# Fairy             1    6.0   6     False    0.0   True
# Fighting          1    3.0   6     False    0.0  False
# Fire              1    3.0   6     False    0.0   True
# Flying            5    5.5   6     False    0.5   True
# Ghost             1    4.0   6     False    0.0   True
# Grass             1    3.5   6     False    0.0   True
# Ground            1    3.0   5     False    0.0   True
# Ice               1    3.0   6     False    0.0   True
# Normal            1    3.0   6     False    0.0   True
# Poison            1    1.5   6     False    0.0  False
# Psychic           1    3.0   6     False    0.0   True
# Rock              1    3.0   6     False    0.0   True
# Steel             2    3.0   6     False    0.0   True
# Water             1    3.0   6     False    0.0   True

# %%
df_pokemons.groupby('Type 1').agg({'HP' : ['max' , 'min'] , 
                                 'Sp. Atk':[np.std , np.median]})
# Out:
#            HP        Sp. Atk
#           max min        std median
# Type 1
# Bug        86   1  26.697055   50.0
# Dark      126  35  33.200952   65.0
# Dragon    125  41  42.257360  105.0
# Electric   90  20  29.740340   95.0
# Fairy     126  35  28.548462   75.0
# Fighting  144  30  28.159345   40.0
# Fire      115  38  30.042121   85.0
# Flying     85  40  34.769479  103.5
# Ghost     150  20  32.561217   65.0
# Grass     123  30  27.244864   75.0
# Ground    115  10  28.135598   47.5
# Ice       110  36  26.604967   77.5
# Normal    255  30  23.946395   50.0
# Poison    105  35  19.322657   60.0
# Psychic   190  20  38.539340   95.0
# Rock      123  30  28.249670   60.0
# Steel     100  40  31.458606   55.0
# Water     170  20  29.030128   70.0

# %% [markdown]
# ## Apply, Apply map, map

# %% [markdown]
# Suponha que precisamos alterar o nome dos pokémons, adicionando o pré-fixo "Pokémon" em seus nomes, separando por underline.
# **Ex.: Pokémon_Bulbasaur**

# %% [markdown]
# ### Revisão Relâmpago de Funções

# %% [markdown]
# Uma função é um bloco de código que recebe alguns parâmetros e retorna um valor. Ex.: Podemos receber a quantidade de horas trabalhadas e o valor da hora de um funcionário e retornar por meio da função o salário daquele mês.

# %% [markdown]
# Para definir uma função precisamos da palavra-chave ```def``` . Além da ```def```, precisamos dar um nome a nossa função. No nosso caso ela irá se chamar calcular_salário. Por fim, ela irá receber 2 parâmetros: quantidade de horas trabalhadas e valor da hora, e então retornar o valor calculado através da palavra-chave ```return```.

# %% [markdown]
# Vamos usar uma função para adicionar o pré-fixo "Pokémon" a qualquer string e return a nova string.

# %%
def adicionar_pokemon(string):
    nova_string = "Pokemon_"+string
    return nova_string

# %%
adicionar_pokemon('Bulbasaur')
# Out:
# 'Pokemon_Bulbasaur'

# %% [markdown]
# Agora, basta nós aplicarmos essa função para todos os pokémons do nosso data frame. Como faríamos isso?

# %% [markdown]
# Uma opção seria por meio de um ```for```.  Mas a opção mais legal seria utilizar o método ```map```.

# %% [markdown]
# ### Map

# %% [markdown]
# Para o método ```map``` passamos:

# %% [markdown]
# O método map irá percorrer item por item e aplicar a função desejada. Exemplo: Tirar a raíz quadrada de cada elemento. Note que já existe uma função que realiza essa tarefa. A criação de funções com ```def``` será para apenas para o caso de funções bem personalizadas. No Numpy temos o ```np.sqrt```.

# %%
# Tirar a raíz  de cada elemento da coluna HP
df_pokemons['HP'].map(np.sqrt)
# Out:
# 0      6.708204
# 1      7.745967
# 2      8.944272
# 3      8.944272
# 4      6.244998
#          ...
# 795    7.071068
# 796    7.071068
# 797    8.944272
# 798    8.944272
# 799    8.944272
# Name: HP, Length: 800, dtype: float64

# %% [markdown]
# ### Apply

# %% [markdown]
# Se quisermos aplicar uma determinada função em todas as linhas de uma vez? Ou em todas as colunas?.<br>
# Use o ```apply```.

# %%
# APlicando a função max para cada coluna
df_pokemons.max()
# Out:
# #                          721
# Name          Zygarde50% Forme
# Type 1                   Water
# HP                         255
# Attack                     190
# Defense                    230
# Sp. Atk                    194
# Sp. Def                    230
# Speed                      180
# Generation                   6
# Legendary                 True
# dtype: object

# %%
# APlicando a função max para cada linha
df_pokemons.max(axis=1)
# Out:
# 0       65.0
# 1       80.0
# 2      100.0
# 3      123.0
# 4       65.0
#        ...
# 795    719.0
# 796    719.0
# 797    720.0
# 798    720.0
# 799    721.0
# Length: 800, dtype: float64

# %% [markdown]
# Note que o valor máximo de cada linha foi retornado.

# %% [markdown]
# Porém, existem funções que não têm esse comportamento. Suponha que queiramos saber a diferença entre o máximo e o mínmo de cada atributo do nosso dataframe.

# %%
def max_min(x):
    diferenca = x.max() - x.min()
    return diferenca

# %% [markdown]
# No nosso exemplo, o x é uma coluna do dataframe. Pra aplicar essa lógica de cálculo em uma coluna, usamos o ```apply```.

# %%
# aplicando o método para algumas colunas
df_pokemons.loc[: , ['HP' , 'Sp. Atk']].apply(max_min)
# Out:
# HP         254
# Sp. Atk    184
# dtype: int64

# %% [markdown]
# ## Applymap

# %% [markdown]
# E se quisermos aplicar alguma transformação para cada elemento do dataframe de uma única vez? <br>
# Use applymap.

# %%
df_pokemons.loc[: , ['HP' , 'Sp. Atk' , 'Attack' , 'Defense']].applymap(np.sqrt)
# Out:
#            HP    Sp. Atk     Attack    Defense
# 0    6.708204   8.062258   7.000000   7.000000
# 1    7.745967   8.944272   7.874008   7.937254
# 2    8.944272  10.000000   9.055385   9.110434
# 3    8.944272  11.045361  10.000000  11.090537
# 4    6.244998   7.745967   7.211103   6.557439
# ..        ...        ...        ...        ...
# 795  7.071068  10.000000  10.000000  12.247449
# 796  7.071068  12.649111  12.649111  10.488088
# 797  8.944272  12.247449  10.488088   7.745967
# 798  8.944272  13.038405  12.649111   7.745967
# 799  8.944272  11.401754  10.488088  10.954451
#
# [800 rows x 4 columns]

# %% [markdown]
# # Exercícios

# %% [markdown]
# **Quizz:**
# * Retorne na tela quantos pokémons de cada Type 2 existem (use o group by).
# * Retorne o máximo de HP, o máximo de Attack e o mínimo de Defesa de Cada Type 1 de pokémon (use agg)

# %%
df_pokemons.groupby('Type 2').size()
# Out:
# Type 2
# Bug          3
# Dark        20
# Dragon      18
# Electric     6
# Fairy       23
# Fighting    26
# Fire        12
# Flying      97
# Ghost       14
# Grass       25
# Ground      35
# Ice         14
# Normal       4
# Poison      34
# Psychic     33
# Rock        14
# Steel       22
# Water       14
# dtype: int64

# %%
df_pokemons.groupby('Type 1').agg({'HP' : 'max' ,'Attack' : 'max' , 'Defense' : 'min'})
# Out:
#            HP  Attack  Defense
# Type 1
# Bug        86     185       30
# Dark      126     150       30
# Dragon    125     180       35
# Electric   90     123       15
# Fairy     126     131       28
# Fighting  144     145       30
# Fire      115     160       37
# Flying     85     115       35
# Ghost     150     165       30
# Grass     123     132       30
# Ground    115     180       25
# Ice       110     130       15
# Normal    255     160        5
# Poison    105     106       35
# Psychic   190     190       15
# Rock      123     165       40
# Steel     100     150       50
# Water     170     155       20
